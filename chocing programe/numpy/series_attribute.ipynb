# %% [markdown]
# # size ,dtype, name ,is_unique,index,values
# | Attribute    | Works On           | Description                 | Example Output   |
# | ------------ | ------------------ | --------------------------- | ---------------- |
# | `.name`      | Series             | Name of the Series          | `'Marks'`        |
# | `.is_unique` | Series             | Checks for duplicate values | `True / False`   |
# | `.index`     | Series / DataFrame | Shows row labels            | `Index([0,1,2])` |
# | `.values`    | Series / DataFrame | Returns NumPy array of data | `array([...])`   |

# %%
import pandas as pd 
data = pd.Series([100, 200, 300], index= True)
print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 data = pd.Series([100, 200, 300], index= True)
#       3 print(data)
#
# File F:\anaconda\Lib\site-packages\pandas\core\series.py:490, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     487 name = ibase.maybe_extract_name(name, data, type(self))
#     489 if index is not None:
# --> 490     index = ensure_index(index)
#     492 if dtype is not None:
#     493     dtype = self._validate_dtype(dtype)
#
# File F:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:7649, in ensure_index(index_like, copy)
#    7647         return Index(index_like, copy=copy, tupleize_cols=False)
#    7648 else:
# -> 7649     return Index(index_like, copy=copy)
#
# ...
