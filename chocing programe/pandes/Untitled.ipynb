# %%
import pandas as pd

col_names = ["Name", "Age", "City"]

df = pd.DataFrame([
    ["Yash", 21, "Indore"],
    ["Rohan", 23, "Delhi"]
], columns=col_names)

print(df)
# Out:
#     Name  Age    City
# 0   Yash   21  Indore
# 1  Rohan   23   Delhi

# %%
ds = {'dfsf':[4,9,5,4,5,4],
      'sdfsf': [56,89,56,49,49,5]
     }
pd.DataFrame(ds)
# Out:
#    dfsf  sdfsf
# 0     4     56
# 1     9     89
# 2     5     56
# 3     4     49
# 4     5     49
# 5     4      5

# %%
df.index.name = "ID"
df
# Out:
#      Name  Age    City
# ID
# 0    Yash   21  Indore
# 1   Rohan   23   Delhi

# %%
ds = pd.read_csv('german_credit_risk.csv')

# %%
ds.size
# Out:
# 11000

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'Job', 'Housing', 'Saving accounts',
#        'Checking account', 'Credit amount', 'Duration', 'Purpose', 'Risk'],
#       dtype='object')

# %% [markdown]
# # decrease the size

# %%
print(ds['Age'].dtype)
print(ds['Age'].size)
ds['Age'] = ds['Age'].astype('int32')
print(ds.size)
# Out:
# int32
# 1000
# 11000
