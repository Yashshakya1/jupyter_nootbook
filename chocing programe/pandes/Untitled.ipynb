# %%
import pandas as pd
# loc and iloc
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]})
print(df)
df.iloc[0] # iloc is a attribute
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0
# brand     Yum Yum
# style         cup
# rating        4.0
# Name: 0, dtype: object

# %% [markdown]
# # column name convert into index using this fuction

# %%
df.set_index('brand')
# Out:
#         style  rating
# brand
# Yum Yum   cup     4.0
# Yum Yum   cup     4.0
# Indomie   cup     3.5
# Indomie  pack    15.0
# Indomie  pack     5.0

# %%
df.loc[4,'brand']
# Out:
# 'Indomie'
