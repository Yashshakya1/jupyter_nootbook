# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 232
#     229     # else interactive menu
#     230     interactive()
# --> 232 if _name_ == "_main_":
#     233     main()
#
# NameError: name '_name_' is not defined
