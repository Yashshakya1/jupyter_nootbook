# %% [markdown]
# # 🎯 What is Classification?
# - Classification is a type of Supervised Machine Learning used to predict categories (labels) instead of numeric values.
# - In simple words:
# - Regression → predicts numbers
# - Classification → predicts categories

# %% [markdown]
# # example spam or not
# | Email Text               | Label    |
# | ------------------------ | -------- |
# | “You won a free iPhone!” | Spam     |
# | “Meeting at 10 AM”       | Not Spam |

# %% [markdown]
# # 📦 Real-Life Examples of Classification
# | Problem              | Input            | Output               |
# | -------------------- | ---------------- | -------------------- |
# | Spam Detection       | Email text       | Spam / Not Spam      |
# | Disease Prediction   | Patient symptoms | Positive / Negative  |
# | Credit Card Fraud    | Transaction data | Fraud / Not Fraud    |
# | Sentiment Analysis   | Customer review  | Positive / Negative  |
# | Image Classification | Image pixels     | Cat / Dog / Car etc. |
