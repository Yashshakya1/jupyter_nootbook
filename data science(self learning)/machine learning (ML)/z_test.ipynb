# %%
import numpy as np 
from scipy.stats import norm

# %%
sample = [172,174,168,169,171,173,175,170,169,172]
population_mean = 170
population_std = 3
sample_mean = np.mean(sample)
n = len(sample)

# %%
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(n))
print(z)
# Out:
# 1.3703203194063098

# %%
# find the p value
p_value = 2* (1-norm.cdf(abs(z_score)))
print(p_value)
# Out:
# 0.17058693287143756

# %%
alfa_value = 0.05
if p_value < alfa_value:
    print("this null hypothesis is reject ")
else:
    print("this null hypothesis is accepted")
# Out:
# this null hypothesis is accepted

# %% [markdown]
# * The Python abs() function return the absolute value. The absolute value of any number is always positive it removes the negative sign of a number in Python.
# *  Cumulative distribution function
