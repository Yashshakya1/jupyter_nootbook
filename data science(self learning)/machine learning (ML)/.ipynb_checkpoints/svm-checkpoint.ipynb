# %% [markdown]
# # SVM

# %% [markdown]
# # 🚀 What is SVM?
#
# * SVM (Support Vector Machine) is a powerful supervised machine learning algorithm used for:
#
# * Classification (main use)
#
# * Regression (SVR)
#
# * Outlier detection (One-class SVM)
#
# * It finds the best separating boundary (hyperplane) between classes.

# %% [markdown]
# # 🧠 How SVM Works (Simple Explanation)
#
# SVM tries to:
#
# ✔ 1. Find the best line/plane that separates the classes
#
# In 2D → line
# In 3D → plane
# In higher dimensions → hyperplane

# %% [markdown]
# # ✔ 4. Use Kernel Trick for non-linear data
#
# If data is not linearly separable, SVM uses a kernel to transform the data into a higher dimension where it becomes linear.
#
# Common kernels:
#
# * linear
#
# * polynomial
#
# * rbf (best for non-linear data)
#
# * sigmoid

# %% [markdown]
# | Kernel  | Use Case                                |
# | ------- | --------------------------------------- |
# | linear  | when data is already linearly separable |
# | poly    | when data has polynomial patterns       |
# | rbf     | best for non-linear data                |
# | sigmoid | rarely used                             |

# %% [markdown]
# # 🧩 Real-Life Example
#
# Imagine separating red and blue balls on a table.
#
# If you draw a line:
#
# Many lines can separate them
#
# But SVM picks the line that gives maximum distance from nearest balls

# %% [markdown]
# # 📊 Types of SVM
# 1. Linear SVM
#
# When classes are linearly separable.
#
# 2. Non-linear SVM
#
# Uses kernel trick for complex data.
#
# 3. SVM for Regression
#
# Called SVR (Support Vector Regression).

# %% [markdown]
# # 🔥 Advantages of SVM
#
# * Works well with high-dimensional data
#
# * Effective with small datasets
#
# * Strong against overfitting
#
# * Can handle non-linear data using kernels

# %% [markdown]
# # ⚠ Limitations of SVM
#
# * Not good for very large datasets
#
# * Hard to choose the right kernel
#
# * Training time is slow for big data

# %% [markdown]
# # creat independed and depended variable

# %%
import pandas as pd 
ds = pd.read_csv('iris_sample_dataset.csv')
ds
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0            6.8           3.2            5.9           2.3   Iris-virginica
# 1            6.9           3.1            5.1           2.3   Iris-virginica
# 2            4.9           3.0            1.4           0.2      Iris-setosa
# 3            5.6           3.0            4.5           1.5  Iris-versicolor
# 4            4.8           3.1            1.6           0.2      Iris-setosa
# 5            5.8           2.8            5.1           2.4   Iris-virginica
# 6            7.2           3.6            6.1           2.5   Iris-virginica
# 7            5.1           3.5            1.4           0.3      Iris-setosa
# 8            4.7           3.2            1.6           0.2      Iris-setosa
# 9            6.6           3.0            4.4           1.4  Iris-versicolor

# %%
# creat independed and depended variable 
x = ds.iloc[:,0:4]
y = ds.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
len(x_train)
# Out:
# 8

# %%
len(x_test)
# Out:
# 2

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
model.predict(x_test)
# Out:
# array(['Iris-virginica', 'Iris-setosa'], dtype=object)

# %%
x_test
# y_test
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            6.8           3.2            5.9           2.3
# 4            4.8           3.1            1.6           0.2

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
param_grid = {
    'kernel': ['linear', 'rbf', 'poly'],
    'C': [0.1, 1, 10, 50],
    'gamma': ['scale', 'auto']
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(SVC(), param_grid,cv=3)
grid.fit(x_train,y_train)
print(grid.best_params_)
print(grid.best_score_)
result = pd.DataFrame(grid.cv_results_)
result
# Out:
# F:\anaconda\Lib\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(
# {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 1.0
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.006014  2.816208e-03         0.003341    1.242614e-03      0.1
# 1        0.003999  1.413550e-03         0.003004    7.972071e-04      0.1
# 2        0.003990  7.885183e-04         0.003332    4.695188e-04      0.1
# 3        0.002999  1.123916e-07         0.002678    4.797576e-04      0.1
# 4        0.002989  1.496329e-05         0.002018    2.170555e-05      0.1
# 5        0.002999  2.213858e-06         0.002654    9.212792e-04      0.1
# 6        0.002681  4.820676e-04         0.002668    4.724679e-04      1.0
# 7        0.002984  1.334434e-05         0.003003    2.796270e-06      1.0
# 8        0.002999  7.867412e-07         0.002336    4.707000e-04      1.0
# 9        0.002999  1.461091e-06         0.003682    2.378262e-03      1.0
# 10       0.003996  3.754620e-06         0.002988    1.574566e-05      1.0
# 11       0.004348  4.583472e-04         0.004652    1.234252e-03      1.0
# 12       0.003651  4.619920e-04         0.002685    4.838075e-04     10.0
# 13       0.003346  4.627535e-04         0.002668    4.705851e-04     10.0
# 14       0.003011  1.703428e-05         0.002661    4.654304e-04     10.0
# 15       0.002997  2.725351e-06         0.001999    5.619580e-07     10.0
# 16       0.003000  6.257699e-07         0.001997    3.104532e-06     10.0
# 17       0.005004  1.634435e-03         0.003348    1.265873e-03     10.0
# 18       0.003001  1.296163e-06         0.002678    4.799129e-04     50.0
# 19       0.002997  3.888489e-06         0.003004    1.808772e-06     50.0
# 20       0.002984  1.984213e-05         0.002667    4.710895e-04     50.0
# 21       0.002998  2.540647e-06         0.002671    4.741244e-04     50.0
# 22       0.002667  4.722138e-04         0.002336    4.701001e-04     50.0
# 23       0.003343  4.886811e-04         0.002339    4.763181e-04     50.0
#
#    param_gamma param_kernel                                            params  \
# 0        scale       linear  {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 1        scale          rbf     {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 2        scale         poly    {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}
# 3         auto       linear   {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}
# 4         auto          rbf      {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}
# 5         auto         poly     {'C': 0.1, 'gamma': 'auto', 'kernel': 'poly'}
# 6        scale       linear    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 7        scale          rbf       {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 8        scale         poly      {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 9         auto       linear     {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 10        auto          rbf        {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 11        auto         poly       {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 12       scale       linear   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 13       scale          rbf      {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 14       scale         poly     {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 15        auto       linear    {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 16        auto          rbf       {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 17        auto         poly      {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 18       scale       linear   {'C': 50, 'gamma': 'scale', 'kernel': 'linear'}
# 19       scale          rbf      {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}
# 20       scale         poly     {'C': 50, 'gamma': 'scale', 'kernel': 'poly'}
# 21        auto       linear    {'C': 50, 'gamma': 'auto', 'kernel': 'linear'}
# 22        auto          rbf       {'C': 50, 'gamma': 'auto', 'kernel': 'rbf'}
# 23        auto         poly      {'C': 50, 'gamma': 'auto', 'kernel': 'poly'}
#
#     split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0            0.666667           0.666667                0.5         0.611111
# 1            0.666667           0.666667                0.5         0.611111
# 2            1.000000           0.666667                0.5         0.722222
# 3            0.666667           0.666667                0.5         0.611111
# 4            0.666667           0.666667                0.5         0.611111
# 5            1.000000           1.000000                0.5         0.833333
# 6            1.000000           1.000000                1.0         1.000000
# 7            0.666667           0.666667                0.5         0.611111
# 8            1.000000           1.000000                0.5         0.833333
# 9            1.000000           1.000000                1.0         1.000000
# 10           0.666667           0.666667                0.5         0.611111
# 11           1.000000           1.000000                0.5         0.833333
# 12           1.000000           1.000000                1.0         1.000000
# 13           1.000000           1.000000                1.0         1.000000
# 14           1.000000           1.000000                0.5         0.833333
# 15           1.000000           1.000000                1.0         1.000000
# 16           1.000000           1.000000                1.0         1.000000
# 17           1.000000           1.000000                0.5         0.833333
# 18           1.000000           1.000000                1.0         1.000000
# 19           1.000000           1.000000                1.0         1.000000
# 20           1.000000           1.000000                0.5         0.833333
# 21           1.000000           1.000000                1.0         1.000000
# 22           1.000000           1.000000                1.0         1.000000
# 23           1.000000           1.000000                0.5         0.833333
#
#     std_test_score  rank_test_score
# 0         0.078567               19
# 1         0.078567               19
# 2         0.207870               18
# 3         0.078567               19
# 4         0.078567               19
# 5         0.235702               11
# 6         0.000000                1
# 7         0.078567               19
# 8         0.235702               11
# 9         0.000000                1
# 10        0.078567               19
# 11        0.235702               11
# 12        0.000000                1
# 13        0.000000                1
# 14        0.235702               11
# 15        0.000000                1
# 16        0.000000                1
# 17        0.235702               11
# 18        0.000000                1
# 19        0.000000                1
# 20        0.235702               11
# 21        0.000000                1
# 22        0.000000                1
# 23        0.235702               11

# %%
result[['param_C','param_kernel','mean_test_score']]
# Out:
#     param_C param_kernel  mean_test_score
# 0       0.1       linear         0.611111
# 1       0.1          rbf         0.611111
# 2       0.1         poly         0.722222
# 3       0.1       linear         0.611111
# 4       0.1          rbf         0.611111
# 5       0.1         poly         0.833333
# 6       1.0       linear         1.000000
# 7       1.0          rbf         0.611111
# 8       1.0         poly         0.833333
# 9       1.0       linear         1.000000
# 10      1.0          rbf         0.611111
# 11      1.0         poly         0.833333
# 12     10.0       linear         1.000000
# 13     10.0          rbf         1.000000
# 14     10.0         poly         0.833333
# 15     10.0       linear         1.000000
# 16     10.0          rbf         1.000000
# 17     10.0         poly         0.833333
# 18     50.0       linear         1.000000
# 19     50.0          rbf         1.000000
# 20     50.0         poly         0.833333
# 21     50.0       linear         1.000000
# 22     50.0          rbf         1.000000
# 23     50.0         poly         0.833333

# %%
# explore the pproperty on gridsearchcv
dir(grid)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_check_refit_for_multimetric',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_format_results',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_routed_params_for_fit',
#  '_get_scorers',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_required_parameters',
#  '_run_search',
#  '_select_best_index',
#  '_sk_visual_block_',
#  '_validate_data',
#  '_validate_params',
#  'best_estimator_',
#  'best_index_',
#  'best_params_',
#  'best_score_',
#  'classes_',
#  'cv',
#  'cv_results_',
#  'decision_function',
#  'error_score',
#  'estimator',
#  'feature_names_in_',
#  'fit',
#  'get_metadata_routing',
#  'get_params',
#  'inverse_transform',
#  'multimetric_',
#  'n_features_in_',
#  'n_jobs',
#  'n_splits_',
#  'param_grid',
#  'pre_dispatch',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'refit',
#  'refit_time_',
#  'return_train_score',
#  'score',
#  'score_samples',
#  'scorer_',
#  'scoring',
#  'set_params',
#  'transform',
#  'verbose']

# %%
grid.best_score_
# Out:
# 1.0

# %% [markdown]
# # A generalization model in machine learning means:
#
# * A model that performs well not only on the training data but also on unseen (new) data.

# %% [markdown]
# # 🌟 5. SVM Interview Questions & Answers
# * ❓Q1: Why SVM is good for high-dimensional data?
#
# * ✔ Because margin maximization works well even in large feature spaces.
#
# * ❓Q2: What is the kernel trick?
#
# * ✔ A method that allows SVM to work in high-dimensional space without actually computing the transformation.
#
# * ❓Q3: What is C parameter?
#
# * ✔ Controls trade-off between margin width and classification errors.
#
# * ❓Q4: What is gamma (in RBF)?
#
# * ✔ Controls the influence of each point.
# * Small gamma → smooth boundary
# * High gamma → very tight, may overfit

# %% [markdown]
# # 🧠 Final Answer (Short Version)
#
# * SVM can be used for regression via SVR,
# but it is less popular because:
#
# * It is slow on big datasets
#
# * It is difficult to tune
#
# * It is harder to interpret
#
# * Better alternatives exist (RF, XGBoost)
#
# * But SVR is excellent for small, clean, non-linear regression problems.
