# %% [markdown]
# # 🎯 What is MAE (Mean Absolute Error)?
#
# * MAE is a metric used to measure how far your predictions are from the actual values, on average

# %% [markdown]
# # 📘 Intuitive Example
#
# * Suppose you have a model that predicts house prices:
#
# * | Actual Price (₹) | Predicted Price (₹) | Error = |Actual - Predicted| |
# * |------------------|---------------------|--------------------------------|
# * | 500,000 | 480,000 | 20,000 |
# * | 600,000 | 630,000 | 30,000 |
# * | 550,000 | 540,000 | 10,000 |
# * | 700,000 | 690,000 | 10,000 |
#
# * MAE = (20,000 + 30,000 + 10,000 + 10,000) / 4 = 17,500
#
# ✅ Interpretation:
# On average, your model’s prediction is ₹17,500 away from the actual price.

# %% [markdown]
# # 🧠 Why We Use MAE
#
# * Easy to interpret → It’s in the same units as your target (like ₹, kg, °C, etc.)
#
# * Robust → It treats all errors equally (no squaring).
#
# * Good for real-world data when outliers shouldn’t dominate.

# %% [markdown]
# # ⚠️ Limitations
#
# * MAE does not penalize large errors heavily — all errors are treated the same.
#
# * If your dataset has outliers, they might not be represented strongly enough.

# %%
from sklearn.metrics import mean_absolute_error
# data house price
ap_actual_price = [500000,600000,550000,700000]
pp_predected_price = [480000,630000,540000,690000]

mae = mean_absolute_error(ap_actual_price,pp_predected_price)
print('Mean Absoulte Error :-', mae)
# Out:
# Mean Absoulte Error :- 17500.0

# %% [markdown]
# | Metric             | Formula Summary           | Penalizes Large Errors? | Use When                               |      |                           |
# | ------------------ | ------------------------- | ----------------------- | -------------------------------------- | ---- | ------------------------- |
# | **MAE**            | Average of                | errors                  |                                        | ❌ No | You want interpretability |
# | **MSE**            | Average of squared errors | ✅ Yes                   | You want to punish large errors        |      |                           |
# | **RMSE**           | √MSE                      | ✅ Yes                   | You want error in same units as target |      |                           |
# | **R² (R-Squared)** | 1 - (SSR/SST)             | —                       | You want model performance ratio       |      |                           |
