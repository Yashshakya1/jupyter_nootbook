# %% [markdown]
# # map()
# * map is function which is used if you went change any string data to the numberical

# %%
import pandas as pd 
d = {'UK': 0, 'USA': 1, 'N': 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)

print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 d = {'UK': 0, 'USA': 1, 'N': 2}
# ----> 3 df['Nationality'] = df['Nationality'].map(d)
#       4 d = {'YES': 1, 'NO': 0}
#       5 df['Go'] = df['Go'].map(d)
#
# NameError: name 'df' is not defined
