# %%
import matplotlib.pyplot as plt 
import numpy as np 
scros = np.random.randint(1,100,200)
plt.hist(scros,bins = 5, color = "purple" , ec = "black",label="data")
print(scros)
plt.xlabel("scores")
plt.ylabel("student")
plt.title("student marks between the 50")
plt.legend()
plt.show()
# Out:
# [35 49 99 75 73 73 33 95 57 39 45 13 34 85 70 58 82 36  9 54 69 19 85 32
#  69 47 36 56 60 96 49 63 18 71  7 98 71  2 72 83 98 41 80 77 51 19 95 57
#  94 28 25 76 20 80 40 65 31 54 93  5 79  1 82 78 23 57 51 55 26 23 86 26
#  37 18 46 89 69 47  5 80 74 73 90  8 11 23 64 67 14 79 19 82 47 74 94 21
#  83 84  6 36 35 66 46 38 43 56 73 57 13 33 45 53 98 17  9 57 76 66 27 69
#  95 16 74 29 69 20 67 24 88 95 24 53 49 99 87 47 52 91 49 17 20 43 35 20
#   9 61 72 34 75 95 15 58 64 27 71 68 35 76 16  5  4 36  2 58  4 64  9 94
#  66  4 94 43 62 10 98 46 23 33 24 56 20  1 51 15  2  9 42 68 96 43 12 15
#  82 68 56 22 98 46 73 27]
