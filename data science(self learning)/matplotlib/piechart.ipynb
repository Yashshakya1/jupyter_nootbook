# %%
# make sure you only maximum 5 catagery in your pie chart this commit for the suggestion  
import matplotlib.pyplot as plt 
programing_language = ["python","javascript","java","go lang","Rust"]
used = [1000,800,700,500,100]
plt.title("top 5 progrmaing language ")
plt.pie(used,labels = programing_language,autopct= "%1.f%%",colors= ["Yellow","pink","orange","blue","red"])
plt.show()
